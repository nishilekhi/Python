# %%
A=int(input("enter first number"))
B=int(input("enter second number"))
C=int(input("enter third number"))
if A and B and C:
  print("It means all three are not zero")
else:
  print("at least one is zero")
# Out:
# enter first number3
# enter second number4
# enter third number5
# It means all three are not zero

# %%
A =int(input("enter first number "))
B =int(input("enter second number "))
C =int(input("enter third number "))
if A > 0 or B > 0 or C > 0:
  print("Atleast one number is greater than zero, thats why condition is true.")
else:
  print("None is greater than zero.")
# Out:
# enter first number 1
# enter second number 2
# enter third number 3
# Atleast one number is greater than zero, thats why condition is true.

# %%
A =int(input("enter first number "))
B =int(input("enter second number "))
C =int(input("enter third number "))
print(A!=B)
print(B!=C)
# Out:
# enter first number 2
# enter second number 3
# enter third number 3
# True
# False

# %%
weight=int(input("What is your weight?"))
height=int(input("What is your height?"))
w=weight/(height**2)
print(f"Your body mass index is {w}.")
if w<18:
  print("underweight")
elif w<25:
  print("fit")
elif w<30:
  print("obeise")
else:
  print("You are amazing!")
# Out:
# What is your weight?30
# What is your height?2
# Your body mass index is 7.5.
# underweight
